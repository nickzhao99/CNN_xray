# %%
from __future__ import print_function, division
import torchvision
from torchvision import transforms,models,datasets
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.nn as nn
import pandas as pd
import os
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# %%
pneumonia_frame = pd.read_csv("C:/Users/Nick/Documents/GitHub/CNN-pneumonia/data_metadata.csv")
pneumonia_frame = pneumonia_frame.iloc[:,1:3]
img_label_dict = pneumonia_frame.set_index('X_ray_image_name').to_dict()
img_label_dict = img_label_dict["Label"]
df = pd.get_dummies(pneumonia_frame, columns=['Label'])
labels = df.iloc[:,1:2]
labels = labels.values
labels
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8)

# %%
classes = ["Normal", "Pneumonia"]

# %%
data_dir = {
            'train': "C:/Users/Nick/Documents/GitHub/CNN-pneumonia/data/train/",
            'test': "C:/Users/Nick/Documents/GitHub/CNN-pneumonia/data/test/"
            }

# %%
batch_size = 10 # we will set the batch size to 64 

transform = {
            'train': transforms.Compose([
                        transforms.RandomResizedCrop(size=256, scale=(0.8,1.0)),
                        transforms.RandomRotation(degrees=15),
                        transforms.ColorJitter(),
                        transforms.RandomHorizontalFlip(),
                        transforms.CenterCrop(size=224),
                        transforms.ToTensor(),
                        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
                    ]),
    
            'test': transforms.Compose([
                        transforms.Resize(size=256),
                        transforms.ToTensor(),
                        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
                    ])
            }

# %%
trainset = torchvision.datasets.ImageFolder(data_dir['train'] , transform = transform['train'])

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,shuffle=True)

# %%
trainset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 5309
#     Root Location: C:/Users/Nick/Documents/GitHub/CNN-pneumonia/data/train/
#     Transforms (if any): Compose(
#                              RandomResizedCrop(size=(256, 256), scale=(0.8, 1.0), ratio=(0.75, 1.3333), interpolation=PIL.Image.BILINEAR)
#                              RandomRotation(degrees=(-15, 15), resample=False, expand=False)
#                              ColorJitter(brightness=0, contrast=0, saturation=0, hue=0)
#                              RandomHorizontalFlip(p=0.5)
#                              CenterCrop(size=(224, 224))
#                              ToTensor()
#                              Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#                          )
#     Target Transforms (if any): None

# %%
import matplotlib.pyplot as plt
import numpy as np

def imshow(img):
    img = img    # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(10)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Normal Normal Normal Normal Normal Normal Normal Normal Normal Normal
